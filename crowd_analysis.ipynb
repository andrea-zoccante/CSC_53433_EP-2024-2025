# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data into a DataFrame
df = pd.read_csv("Assets/AnimalResourceData.csv")

df['Timestamp'] = pd.to_datetime(df['Timestamp'])
window_size = 1000
df['Animals_MA'] = df['NAnimals'].rolling(window=window_size).mean()
df['Resources_MA'] = df['NResources'].rolling(window=window_size).mean()
df['NFemales_MA'] = df['NFemales'].rolling(window=window_size).mean()
df['NMales_MA'] = df['NMales'].rolling(window=window_size).mean()
df['MeanLifeSuccess_MA'] = df['MeanLifeSuccess'].rolling(window=window_size).mean()
df['MeanAge_MA'] = df['MeanAge'].rolling(window=window_size).mean()

# %%
df.head(10)
# Out:
#             Timestamp  NAnimals  NResources  NFemales  NMales  \
# 0 2024-12-06 11:45:57       100           0        51      49
# 1 2024-12-06 11:45:57       100           0        51      49
# 2 2024-12-06 11:45:58       100           1        51      49
# 3 2024-12-06 11:45:58       100           2        51      49
# 4 2024-12-06 11:45:58       100           3        51      49
# 5 2024-12-06 11:45:58       100           4        51      49
# 6 2024-12-06 11:45:58       100           5        51      49
# 7 2024-12-06 11:45:58       100           6        51      49
# 8 2024-12-06 11:45:58       100           7        51      49
# 9 2024-12-06 11:45:58       100           8        51      49
#
#    MeanLifeSuccess  MeanAge  %MatingAccept  Animals_MA  Resources_MA  \
# 0             0.00      0.0            0.0         NaN           NaN
# 1             0.00      0.0            0.0         NaN           NaN
# 2             0.99      1.0            0.0         NaN           NaN
# ...

# %%
# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot Number of Animals with moving average
axes[0].plot(df['Timestamp'], df['NAnimals'], label='Number of Animals')
axes[0].plot(df['Timestamp'], df['Animals_MA'], color='red', linestyle='--', label=f'Moving Average ({window_size})')
axes[0].set_title('Number of Animals Over Time')
axes[0].set_xlabel('Timestamp')
axes[0].set_ylabel('Number of Animals')
axes[0].grid(True)
axes[0].legend()

# Plot Number of Resources with moving average
axes[1].plot(df['Timestamp'], df['NResources'], color='orange', label='Number of Resources')
axes[1].plot(df['Timestamp'], df['Resources_MA'], color='green', linestyle='--', label=f'Moving Average ({window_size})')
axes[1].set_title('Number of Resources Over Time')
axes[1].set_xlabel('Timestamp')
axes[1].set_ylabel('Number of Resources')
axes[1].grid(True)
axes[1].legend()

# Adjust layout and show
plt.tight_layout()
plt.show()

# %%
# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(df['Timestamp'], df['NFemales'], label='Number of Females')
axes[0].plot(df['Timestamp'], df['NMales'], color='red', linestyle='--', label=f'Number of Males')
axes[0].set_title('Count per Gender Over Time')
axes[0].set_xlabel('Timestamp')
axes[0].set_ylabel('Count per Gender')
axes[0].grid(True)
axes[0].legend()

axes[1].plot(df['Timestamp'], df['NFemales_MA'], color='orange', label=f'Females Moving Average ({window_size})')
axes[1].plot(df['Timestamp'], df['NMales_MA'], color='green', linestyle='--', label=f'Males Moving Average ({window_size})')
axes[1].set_title('Number of Resources Over Time')
axes[1].set_xlabel('Timestamp')
axes[1].set_ylabel('Number of Resources')
axes[1].grid(True)
axes[1].legend()

# Adjust layout and show
plt.tight_layout()
plt.show()

# %%
# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(df['Timestamp'], df['NAnimals'], label='Number of Animals')
axes[0].plot(df['Timestamp'], df['Animals_MA'], color='red', linestyle='--', label=f'Moving Average ({window_size})')
axes[0].set_title('Number of Animals Over Time')
axes[0].set_xlabel('Timestamp')
axes[0].set_ylabel('Number of Animals')
axes[0].grid(True)
axes[0].legend()

axes[1].plot(df['Timestamp'], df['MeanLifeSuccess'], color='orange', label=f'Mean Life Success')
axes[1].plot(df['Timestamp'], df['MeanLifeSuccess_MA'], color='green', linestyle='--', label=f'Moving Average ({window_size})')
axes[1].set_title('Mean Life Success Over Time')
axes[1].set_xlabel('Timestamp')
axes[1].set_ylabel('Mean Life Success')
axes[1].grid(True)
axes[1].legend()

# Adjust layout and show
plt.tight_layout()
plt.show()

# %%
# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(df['Timestamp'], df['MeanAge'], label='Mean Age')
axes[0].plot(df['Timestamp'], df['MeanAge_MA'], color='red', linestyle='--', label=f'Moving Average ({window_size})')
axes[0].set_title('Mean Age Over Time')
axes[0].set_xlabel('Timestamp')
axes[0].set_ylabel('Mean Age')
axes[0].grid(True)
axes[0].legend()

axes[1].plot(df['Timestamp'], df['MeanLifeSuccess'], color='orange', label=f'Mean Life Success')
axes[1].plot(df['Timestamp'], df['MeanLifeSuccess_MA'], color='green', linestyle='--', label=f'Moving Average ({window_size})')
axes[1].set_title('Mean Life Success over Time')
axes[1].set_xlabel('Timestamp')
axes[1].set_ylabel('Mean Life Success')
axes[1].grid(True)
axes[1].legend()

# Adjust layout and show
plt.tight_layout()
plt.show()
